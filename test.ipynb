# %%
import pandas as pd
s = pd.Series([0.05, 0.05, 0.05])
print(s.mean(), s.std(), (s - s.mean()) / s.std())
# Out:
# 0.05000000000000001 8.498374721940739e-18 0   -0.816497
# 1   -0.816497
# 2   -0.816497
# dtype: float64
